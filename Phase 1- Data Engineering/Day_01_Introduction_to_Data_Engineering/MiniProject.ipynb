# %%
df = pd.read_csv('student_management.csv')
df["total_score"] = df["math_score"] + df["programming_score"]

# %%
df.describe()

# %%
df["department"].value_counts()

# %%
print( df["math_score"].max())
print( df["math_score"].min())
print( df["math_score"].mean())
print( df["programming_score"].mean())
print(df["attendance_percentage"].mean())

# %%
print(df.groupby("gender")["total_score"].mean())

# %%
top_students = df.sort_values(by="total_score", ascending=False).head(5)

print(top_students[["name", "department", "total_score"]])

# %%
low_attendance = df[df["attendance_percentage"] < 75]
